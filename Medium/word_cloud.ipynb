# %%
texts = [
    "Python is a popular programming language.",
    "NLP is a field of artificial intelligence that focuses on the interaction between computers and human language.",
    "Sentiment analysis is the process of classifying the emotional intent of text.",
    "Machine learning is an important application of AI.",
    "Natural Language Processing is used for text analysis.",
    "Python libraries like scikit-learn and NLTK are used in NLP.",
    "AI and machine learning are transforming industries.",
    "If you are interested in NLP, stay tuned!"
]

# %%
import re

def clean_text(text):
    clean_txt = text.lower()
    # Clear characters other than numbers and letters of the alphabet only
    clean_txt = re.sub(r'[^0-9a-zçğıiöşü\s]', '', clean_txt,
                       flags=re.IGNORECASE)  

    return ' '.join(sorted(clean_txt.split()))


cleaned_texts = [clean_text(text) for text in texts]
cleaned_texts
# Out:
# ['a is language popular programming python',
#  'a and artificial between computers field focuses human intelligence interaction is language nlp of on that the',
#  'analysis classifying emotional intent is of of process sentiment text the the',
#  'ai an application important is learning machine of',
#  'analysis for is language natural processing text used',
#  'and are in libraries like nlp nltk python scikitlearn used',
#  'ai and are industries learning machine transforming',
#  'are if in interested nlp stay tuned you']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(cleaned_texts)
tfidf_feature_names = vectorizer.get_feature_names_out()

tfidf_array = tfidf_matrix.toarray()
df = pd.DataFrame(data=tfidf_array, columns=tfidf_feature_names, index=cleaned_texts)
df
# Out:
#                                                           ai        an  \
# a is language popular programming python            0.000000  0.000000
# a and artificial between computers field focuse...  0.000000  0.000000
# analysis classifying emotional intent is of of ...  0.000000  0.000000
# ai an application important is learning machine of  0.343718  0.410127
# analysis for is language natural processing tex...  0.000000  0.000000
# and are in libraries like nlp nltk python sciki...  0.000000  0.000000
# ai and are industries learning machine transfor...  0.369189  0.000000
# are if in interested nlp stay tuned you             0.000000  0.000000
#
#                                                     analysis       and  \
# a is language popular programming python            0.000000  0.000000
# a and artificial between computers field focuse...  0.000000  0.199739
# analysis classifying emotional intent is of of ...  0.245843  0.000000
# ai an application important is learning machine of  0.000000  0.000000
# analysis for is language natural processing tex...  0.343718  0.000000
# and are in libraries like nlp nltk python sciki...  0.000000  0.261025
# ai and are industries learning machine transfor...  0.000000  0.318580
# are if in interested nlp stay tuned you             0.000000  0.000000
#
#                                                     application       are  \
# a is language popular programming python               0.000000  0.000000
# a and artificial between computers field focuse...     0.000000  0.000000
# analysis classifying emotional intent is of of ...     0.000000  0.000000
# ai an application important is learning machine of     0.410127  0.000000
# analysis for is language natural processing tex...     0.000000  0.000000
# and are in libraries like nlp nltk python sciki...     0.000000  0.261025
# ai and are industries learning machine transfor...     0.000000  0.318580
# are if in interested nlp stay tuned you                0.000000  0.278390
#
#                                                     artificial  between  \
# a is language popular programming python               0.00000  0.00000
# a and artificial between computers field focuse...     0.27619  0.27619
# analysis classifying emotional intent is of of ...     0.00000  0.00000
# ai an application important is learning machine of     0.00000  0.00000
# analysis for is language natural processing tex...     0.00000  0.00000
# and are in libraries like nlp nltk python sciki...     0.00000  0.00000
# ai and are industries learning machine transfor...     0.00000  0.00000
# are if in interested nlp stay tuned you                0.00000  0.00000
#
#                                                     classifying  computers  \
# a is language popular programming python               0.000000    0.00000
# a and artificial between computers field focuse...     0.000000    0.27619
# analysis classifying emotional intent is of of ...     0.293341    0.00000
# ai an application important is learning machine of     0.000000    0.00000
# analysis for is language natural processing tex...     0.000000    0.00000
# and are in libraries like nlp nltk python sciki...     0.000000    0.00000
# ai and are industries learning machine transfor...     0.000000    0.00000
# are if in interested nlp stay tuned you                0.000000    0.00000
#
#                                                     ...  scikitlearn  \
# a is language popular programming python            ...     0.000000
# a and artificial between computers field focuse...  ...     0.000000
# analysis classifying emotional intent is of of ...  ...     0.000000
# ai an application important is learning machine of  ...     0.000000
# analysis for is language natural processing tex...  ...     0.000000
# and are in libraries like nlp nltk python sciki...  ...     0.360934
# ai and are industries learning machine transfor...  ...     0.000000
# are if in interested nlp stay tuned you             ...     0.000000
#
#                                                     sentiment      stay  \
# a is language popular programming python             0.000000  0.000000
# a and artificial between computers field focuse...   0.000000  0.000000
# analysis classifying emotional intent is of of ...   0.293341  0.000000
# ai an application important is learning machine of   0.000000  0.000000
# analysis for is language natural processing tex...   0.000000  0.000000
# and are in libraries like nlp nltk python sciki...   0.000000  0.000000
# ai and are industries learning machine transfor...   0.000000  0.000000
# are if in interested nlp stay tuned you              0.000000  0.384946
#
#                                                         text     that  \
# a is language popular programming python            0.000000  0.00000
# a and artificial between computers field focuse...  0.000000  0.27619
# analysis classifying emotional intent is of of ...  0.245843  0.00000
# ai an application important is learning machine of  0.000000  0.00000
# analysis for is language natural processing tex...  0.343718  0.00000
# and are in libraries like nlp nltk python sciki...  0.000000  0.00000
# ai and are industries learning machine transfor...  0.000000  0.00000
# are if in interested nlp stay tuned you             0.000000  0.00000
#
#                                                          the  transforming  \
# a is language popular programming python            0.000000      0.000000
# a and artificial between computers field focuse...  0.231469      0.000000
# analysis classifying emotional intent is of of ...  0.491685      0.000000
# ai an application important is learning machine of  0.000000      0.000000
# analysis for is language natural processing tex...  0.000000      0.000000
# and are in libraries like nlp nltk python sciki...  0.000000      0.000000
# ai and are industries learning machine transfor...  0.000000      0.440518
# are if in interested nlp stay tuned you             0.000000      0.000000
#
#                                                        tuned      used  \
# a is language popular programming python            0.000000  0.000000
# a and artificial between computers field focuse...  0.000000  0.000000
# analysis classifying emotional intent is of of ...  0.000000  0.000000
# ai an application important is learning machine of  0.000000  0.000000
# analysis for is language natural processing tex...  0.000000  0.343718
# and are in libraries like nlp nltk python sciki...  0.000000  0.302491
# ai and are industries learning machine transfor...  0.000000  0.000000
# are if in interested nlp stay tuned you             0.384946  0.000000
#
#                                                          you
# a is language popular programming python            0.000000
# a and artificial between computers field focuse...  0.000000
# analysis classifying emotional intent is of of ...  0.000000
# ai an application important is learning machine of  0.000000
# analysis for is language natural processing tex...  0.000000
# and are in libraries like nlp nltk python sciki...  0.000000
# ai and are industries learning machine transfor...  0.000000
# are if in interested nlp stay tuned you             0.384946
#
# [8 rows x 49 columns]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\yogeshkannah\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (2.4.1)
# Requirement already satisfied: pillow in c:\users\yogeshkannah\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (12.0.0)
# Collecting matplotlib (from wordcloud)
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->wordcloud)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->wordcloud)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->wordcloud)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->wordcloud)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\yogeshkannah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Collecting pyparsing>=3 (from matplotlib->wordcloud)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yogeshkannah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\yogeshkannah\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl (307 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.2 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 12.0 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, wordcloud
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [wordcloud]
#    ---------------------------------------- 7/7 [wordcloud]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.2 wordcloud-1.9.6
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\yogeshkannah\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(vectorizer.vocabulary_)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import nltk
from nltk import ngrams
from collections import Counter

text = "I love natural language processing. It is very interesting."

tokens = nltk.word_tokenize(text)

bigrams = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))
print("\nbigrame",bigrams)
print("\ntrigrams",trigrams)
# Out:
# bigrame [('I', 'love'), ('love', 'natural'), ('natural', 'language'), ('language', 'processing'), ('processing', '.'), ('.', 'It'), ('It', 'is'), ('is', 'very'), ('very', 'interesting'), ('interesting', '.')]
#
# trigrams [('I', 'love', 'natural'), ('love', 'natural', 'language'), ('natural', 'language', 'processing'), ('language', 'processing', '.'), ('processing', '.', 'It'), ('.', 'It', 'is'), ('It', 'is', 'very'), ('is', 'very', 'interesting'), ('very', 'interesting', '.')]
