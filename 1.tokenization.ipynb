# %% [markdown]
# Corpus
# Documents
# Vocabulary - Unique words
# Words
#
# Using the NLTK

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\yogeshkannah\Music\AI\.venv\Scripts\python.exe

# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\yogeshkannah\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
corpus  = """Hello, Example Corpus for testing the tokens.
Here is your's simple example to demonstrate the tokenization process.
We will use the NLTK library to tokenize this corpus.
Tokenization is the process of splitting the text into tokens.
Tokens can be words, punctuation marks, or other meaningful units."""

print(corpus)
# Out:
# Hello, Example Corpus for testing the tokens.
# Here is your's simple example to demonstrate the tokenization process.
# We will use the NLTK library to tokenize this corpus.
# Tokenization is the process of splitting the text into tokens.
# Tokens can be words, punctuation marks, or other meaningful units.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\yogeshkannah/nltk_data', 'c:\\Users\\yogeshkannah\\Music\\AI\\.venv\\nltk_data', 'c:\\Users\\yogeshkannah\\Music\\AI\\.venv\\share\\nltk_data', 'c:\\Users\\yogeshkannah\\Music\\AI\\.venv\\lib\\nltk_data', 'C:\\Users\\yogeshkannah\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\yogeshkannah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\yogeshkannah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize
from typing import List
# documents: List[str] = sent_tokenize(corpus)
# print(documents)
sent_tokenize(corpus)
# Out:
# ['Hello, Example Corpus for testing the tokens.',
#  "Here is your's simple example to demonstrate the tokenization process.",
#  'We will use the NLTK library to tokenize this corpus.',
#  'Tokenization is the process of splitting the text into tokens.',
#  'Tokens can be words, punctuation marks, or other meaningful units.']

# %%
print(type(documents))
for sent in documents:
    print(sent)
# Out:
# <class 'list'>
# Hello, Example Corpus for testing the tokens.
# Here is your's simple example to demonstrate the tokenization process.
# We will use the NLTK library to tokenize this corpus.
# Tokenization is the process of splitting the text into tokens.
# Tokens can be words, punctuation marks, or other meaningful units.

# %%
from nltk.tokenize import word_tokenize
# vocab: List[str] = word_tokenize(corpus)
# print(vocab)
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Example',
#  'Corpus',
#  'for',
#  'testing',
#  'the',
#  'tokens',
#  '.',
#  'Here',
#  'is',
#  'your',
#  "'s",
#  'simple',
#  'example',
#  'to',
#  'demonstrate',
#  'the',
#  'tokenization',
#  'process',
#  '.',
#  'We',
#  'will',
#  'use',
#  'the',
#  'NLTK',
#  'library',
#  'to',
#  'tokenize',
#  'this',
#  'corpus',
#  '.',
#  'Tokenization',
#  'is',
#  'the',
#  'process',
#  'of',
#  'splitting',
#  'the',
#  'text',
#  'into',
#  'tokens',
#  '.',
#  'Tokens',
#  'can',
#  'be',
#  'words',
#  ',',
#  'punctuation',
#  'marks',
#  ',',
#  'or',
#  'other',
#  'meaningful',
#  'units',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Example',
#  'Corpus',
#  'for',
#  'testing',
#  'the',
#  'tokens',
#  '.',
#  'Here',
#  'is',
#  'your',
#  "'",
#  's',
#  'simple',
#  'example',
#  'to',
#  'demonstrate',
#  'the',
#  'tokenization',
#  'process',
#  '.',
#  'We',
#  'will',
#  'use',
#  'the',
#  'NLTK',
#  'library',
#  'to',
#  'tokenize',
#  'this',
#  'corpus',
#  '.',
#  'Tokenization',
#  'is',
#  'the',
#  'process',
#  'of',
#  'splitting',
#  'the',
#  'text',
#  'into',
#  'tokens',
#  '.',
#  'Tokens',
#  'can',
#  'be',
#  'words',
#  ',',
#  'punctuation',
#  'marks',
#  ',',
#  'or',
#  'other',
#  'meaningful',
#  'units',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Example',
#  'Corpus',
#  'for',
#  'testing',
#  'the',
#  'tokens.',
#  'Here',
#  'is',
#  'your',
#  "'s",
#  'simple',
#  'example',
#  'to',
#  'demonstrate',
#  'the',
#  'tokenization',
#  'process.',
#  'We',
#  'will',
#  'use',
#  'the',
#  'NLTK',
#  'library',
#  'to',
#  'tokenize',
#  'this',
#  'corpus.',
#  'Tokenization',
#  'is',
#  'the',
#  'process',
#  'of',
#  'splitting',
#  'the',
#  'text',
#  'into',
#  'tokens.',
#  'Tokens',
#  'can',
#  'be',
#  'words',
#  ',',
#  'punctuation',
#  'marks',
#  ',',
#  'or',
#  'other',
#  'meaningful',
#  'units',
#  '.']

# %% [markdown]
# ![image.png](attachment:image.png)
