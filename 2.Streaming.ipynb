# %% [markdown]
# # Stemming:
#
# Stemming is a process of reducing a word to its root form.
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or
# to the roots of words known as a lemma. Stemming is important in natural language understanding
# (NLU) and natural language processing (NLP).
#
#  Classification Problem
#
#  Comments of product is a positive review or negative review
#
#  Reviews ---- > eating, eat, eating --> eat
#
#  Going , Goes, gone --> go

# %%
words = ['writing', 'writer', 'written', 'wrote', 'write','goes','going','gone','go']

# %%
# PorterStemmer

from nltk.stem import PorterStemmer

stemming = PorterStemmer()
for word in words:
    print(word , "---->" , stemming.stem(word))
# Out:
# writing ----> write
# writer ----> writer
# written ----> written
# wrote ----> wrote
# write ----> write
# goes ----> goe
# going ----> go
# gone ----> gone
# go ----> go

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %% [markdown]
# RegexpStemmer class
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular
# Expression Stemmer algorithms. It basically takes a Single regular expression and removes any
# prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)
print(reg_stemmer.stem('writing'))
print(reg_stemmer.stem('eating'))
print(reg_stemmer.stem('eats'))
# Out:
# writ
# eat
# eat

# %% [markdown]
# Snowball Stemmer
#
# It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better
# version of the Porter Stemmer since some issues Of it were fixed in this stemmer,

# %%
# SnowballStemmer

from nltk.stem import SnowballStemmer

snowball_stemming = SnowballStemmer("english")
for word in words:
    print(word , "----->" , snowball_stemming.stem(word))
# Out:
# writing -----> write
# writer -----> writer
# written -----> written
# wrote -----> wrote
# write -----> write
# goes -----> goe
# going -----> go
# gone -----> gone
# go -----> go

# %%
stemming.stem("fairly"), stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowball_stemmer.stem("fairly"), snowball_stemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowball_stemmer.stem("goes"), stemming.stem("goes")
# Out:
# ('goe', 'goe')

# %%
# To Reduce this Limitaion , will goes to lemmatization
